# %% [markdown]
# ## Read in Data

# %%
using CSV, Tables, LinearAlgebra, Random, Gurobi, JuMP, DataFrames, CategoricalArrays, Statistics

# %%
data = CSV.read("team_data_with_averages.csv", DataFrame);

# %%
Random.seed!(8008)
rows = round(Int, .7 * nrow(data))
sample = randperm(nrow(data))[1:rows];
train = data[sample,:];
test = data[Not(sample),:];

# %%
data
# Out:
# 236×129 DataFrame
#  Row │ Tm       year   W      WIN.     avg_G_C  avg_GS_C  avg_MP_C  avg_FG_C   ⋯
#      │ String3  Int64  Int64  Float64  Float64  Float64   Float64   Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ MIL       2020     56    0.767  60.5      32.0      20.5      3.15      ⋯
#    2 │ TOR       2020     53    0.736  30.0      20.6667   19.2667   3.2
#    3 │ LAL       2020     52    0.732  61.5      31.5      18.0      3.0
#    4 │ BOS       2020     48    0.667  31.8      12.8      12.94     2.26
#    5 │ DEN       2020     46    0.63   59.0      33.0      24.65     5.4       ⋯
#    6 │ IND       2020     45    0.616  55.3333   39.6667   24.2667   4.26667
#    7 │ HOU       2020     44    0.611  29.3333   15.3333   17.6      2.9
#    8 │ OKC       2020     44    0.611  39.75     16.0      15.55     2.525
#    9 │ UTA       2020     44    0.611  45.6667   21.3333   18.6333   2.8       ⋯
#   10 │ MIA       2020     44    0.603  54.0      27.5      19.3      2.5
#   11 │ POR       2020     35    0.473  34.3333   20.6667   17.4      3.26667
#   ⋮  │    ⋮       ⋮      ⋮       ⋮        ⋮        ⋮         ⋮         ⋮       ⋱
#  227 │ PHI       2011     41    0.5    48.25     20.5      12.425    1.875
#  228 │ UTA       2011     39    0.476  42.8      16.8      14.34     2.38      ⋯
#  229 │ IND       2011     37    0.451  58.6667   27.6667   19.3333   2.6
#  230 │ MIL       2011     35    0.427  47.5      20.75     15.875    2.075
#  231 │ LAC       2011     32    0.39   56.0      40.5      25.9      4.2
#  232 │ DET       2011     30    0.366  67.0      48.5      25.35     2.5       ⋯
#  233 │ SAC       2011     24    0.293  54.0      36.0      18.2333   2.9
#  234 │ WAS       2011     23    0.28   47.5      37.5      16.4      2.25
#  235 │ TOR       2011     22    0.268  40.3333   25.0      17.5667   3.16667
#  236 │ CLE       2011     19    0.232  60.3333   37.6667   25.7333   3.66667   ⋯
#                                                 121 columns and 215 rows omitted

# %%
C_indices = 5:29
PG_indices = 30:54
PF_indices = 55:79
SF_indices = 80:104
SG_indices = 105:129;

# %%
Xtrain = train[:,5:129]
XtrainC = train[:,C_indices]
XtrainPG = train[:,PG_indices]
XtrainPF = train[:,PF_indices]
XtrainSF = train[:,SF_indices]
XtrainSG = train[:,SG_indices]
ytrain = train[:,4]
# Out:
# 165-element Vector{Float64}:
#  0.89
#  0.232
#  0.712
#  0.463
#  0.451
#  0.611
#  0.354
#  0.256
#  0.5
#  0.61
#  0.598
#  0.695
#  0.606
#  ⋮
#  0.297
#  0.333
#  0.524
#  0.573
#  0.756
#  0.476
#  0.515
#  0.585
#  0.354
#  0.72
#  0.549
#  0.427

# %%
Xtest = test[:,5:129]
XtestC = test[:,C_indices]
XtestPG = test[:,PG_indices]
XtestPF = test[:,PF_indices]
XtestSF = test[:,SF_indices]
XtestSG = test[:,SG_indices]
ytest = test[:,4];

# %%
function pCor(threshold, X)
    n,p = size(X)
    temp = cor(X)
    corPairs = Vector{Tuple{Int, Int}}()
    for i in 1:p
        for j in i+1:p
            if abs(temp[i,j]) > threshold
                push!(corPairs, (i,j))
            end
        end
    end
    return corPairs
end

function newData(X)
    n,p = size(X)
    newX = X[:,1]
    for i in 1:p
        if i != 1
            newX = hcat(newX, X[:,i]) # add not transformed variable first
        end
        newX = hcat(newX, X[:,i].^2) # add squared
        newX = hcat(newX, broadcast(abs, X[:,i]).^.5) # add square root
        newX = hcat(newX, broadcast(log, broadcast(abs, X[:,i]) .+ 1)) # add log + 1
    end
    return newX
end

function calculate_predictions(X, coefficients)
    return Matrix(X) * coefficients
end

function calculate_mse(y_true, y_pred)
    squared_error = (y_true .- y_pred) .^ 2
    return mean(squared_error)
end

function calculate_mae(y_true, y_pred)
    absolute_error = abs.(y_true .- y_pred)
    return mean(absolute_error)
end

function calculate_osr2(y_true, y_pred)
    ssr = sum((y_true - y_pred) .^ 2)
    tss = sum((y_true .- mean(y_true)) .^ 2)
    return 1 - ssr / tss
end
# Out:
# calculate_osr2 (generic function with 1 method)

# %% [markdown]
# ## Holistic Regression

# %%
function holistic(y, X, lambda, threshold, k)
    # Setting initial model
    model = JuMP.Model(Gurobi.Optimizer)
    n,p = size(X)
    # create the variables
    @variable(model, betas[1:p])
    @variable(model, a[1:p] >= 0)
    @variable(model, z[1:p], Bin)
    @objective(model, Min, sum((y[i] - sum(X[i,:].*betas))^2 for i=1:n) + lambda * sum(a[i] for i=1:p))
    # for abs value for l1 norm
    @constraint(model, [i=1:p], betas[i] <= a[i])
    @constraint(model, [i=1:p], betas[i] >= -a[i])
    # for sparsity
    @constraint(model, [i=1:p], betas[i] <= 100*z[i])
    @constraint(model, [i=1:p], betas[i] >= -100*z[i])
    @constraint(model, sum(z[i] for i in 1:p) <= k)
    # for group sparsity
    for i in 0:24
        @constraint(model, sum(z[j] for j in (4*i+1):(4*(i+1))) <= 1)
    end
    # for pairwise colinearity
    pairs = pCor(threshold, X)
    for pair in pairs
        @constraint(model, z[pair[1]] + z[pair[2]] <= 1)
    end
        
    optimize!(model)

    return value.(betas)
end
# Out:
# holistic (generic function with 1 method)

# %%
newXtrain = newData(Xtrain)
newXtrainC = newData(XtrainC)
newXtestC = newData(XtestC);
newXtrainPG = newData(XtrainPG)
newXtestPG = newData(XtestPG);
newXtrainPF = newData(XtrainPF)
newXtestPF = newData(XtestPF);
newXtrainSG = newData(XtrainSG)
newXtestSG = newData(XtestSG);
newXtrainSF = newData(XtrainSF)
newXtestSF = newData(XtestSF);
newXtest = newData(Xtest)
# Out:
# 71×500 Matrix{Float64}:
seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.39602    0   28   46.90579    3.39602  92.8%     -    0s
# H    0     0                       4.2531691    3.39602  20.2%     -    0s
# H    0     0                       4.2070237    3.39602  19.3%     -    0s
#      0     0    3.39625    0   29    4.20702    3.39625  19.3%     -    0s
# H    0     0                       4.1890599    3.39625  18.9%     -    0s
#      0     0    3.48949    0   25    4.18906    3.48949  16.7%     -    0s
# H    0     0                       4.1875897    3.82496  8.66%     -    0s
#      0     2    3.82496    0   25    4.18759    3.82496  8.66%     -    0s
# *   34    26              10       4.0439811    3.82496  5.42%  36.0    0s
#
# Cutting planes:
#   Implied bound: 2
#   Clique: 1
#   Zero half: 1
#   Mod-K: 1
#
# Explored 162 nodes (5916 simplex iterations) in 0.44 seconds (0.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 4.04398 4.18759 4.18906 ... 46.9058
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.043981135349e+00, best bound 4.043981135349e+00, gap 0.0000%
#
# User-callback calls 963, time in user-callback 0.00 sec

# %%
# Calculate predictions
pred = calculate_predictions(newXtestC, C_coeff)
# Calculate metrics
mse = calculate_mse(ytest, pred)
mae = calculate_mae(ytest, pred)
osr2 = calculate_osr2(ytest, pred)
# Print results
println("OSR2: ", osr2)
println("MAE: ", mae)
println("MSE: ", mse)
# Out:
# OSR2: 0.12382498019838217
# MAE: 0.10688283407110818
# MSE: 0.01769288983001332

# %% [markdown]
# The first model is pretty bad. Let's see if we normalizing the data helps.

# %%
C_coeff = holistic(ytrain, newXtrain, 1, .5, 30); # implement the function with lambda = 1, p = 0.5, and k = 8
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8650U CPU @ 1.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11833 rows, 1500 columns and 24214 nonzeros
# Model fingerprint: 0xa71545dc
# Model has 125250 quadratic objective terms
# Variable types: 1000 continuous, 500 integer (500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 5e+05]
#   QObjective range [1e+00, 7e+09]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+01]
# Warning: Model contains large quadratic objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 46.9057890
# Presolve removed 9626 rows and 0 columns
# Presolve time: 0.13s
#
# Explored 0 nodes (0 simplex iterations) in 0.13 seconds (0.09 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 46.9058
#
# Best objective 4.690578900000e+01, best bound -, gap -
#
# User-callback calls 471, time in user-callback 0.00 sec
# Gurobi Error 10020: Objective Q not PSD (diagonal adjustment of 1.0e+08 would be required). Set NonConvex parameter to 2 to solve model.
#
# Stacktrace:
#   [1] _check_ret
#     @ C:\Users\Christian\.julia\packages\Gurobi\W2h9r\src\MOI_wrapper\MOI_wrapper.jl:375 [inlined]
#   [2] _check_ret_GRBoptimize(model::Gurobi.Optimizer)
#     @ Gurobi C:\Users\Christian\.julia\packages\Gurobi\W2h9r\src\MOI_wrapper\MOI_wrapper.jl:392
#   [3] optimize!(model::Gurobi.Optimizer)
#     @ Gurobi C:\Users\Christian\.julia\packages\Gurobi\W2h9r\src\MOI_wrapper\MOI_wrapper.jl:2687
#   [4] optimize!
#     @ C:\Users\iai\builds\InterpretableAI\SystemImage\SysImgBuilder\.julia\packages\MathOptInterface\BlCD1\src\Bridges\bridge_optimizer.jl:376 [inlined]
#   [5] optimize!
#     @ C:\Users\iai\builds\InterpretableAI\SystemImage\SysImgBuilder\.julia\packages\MathOptInterface\BlCD1\src\MathOptInterface.jl:85 [inlined]
#   [6] optimize!(m::MathOptInterface.Utilities.CachingOptimizer{MathOptInterface.Bridges.LazyBridgeOptimizer{Gurobi.Optimizer}, MathOptInterface.Utilities.UniversalFallback{MathOptInterface.Utilities.Model{Float64}}})
#     @ MathOptInterface.Utilities C:\Users\iai\builds\InterpretableAI\SystemImage\SysImgBuilder\.julia\packages\MathOptInterface\BlCD1\src\Utilities\cachingoptimizer.jl:316
#   [7] optimize!(model::Model; ignore_optimize_hook::Bool, _differentiation_backend::MathOptInterface.Nonlinear.SparseReverseMode, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ JuMP C:\Users\iai\builds\InterpretableAI\SystemImage\SysImgBuilder\.julia\packages\JuMP\ptoff\src\optimizer_interface.jl:440
#   [8] optimize!
#     @ C:\Users\iai\builds\InterpretableAI\SystemImage\SysImgBuilder\.julia\packages\JuMP\ptoff\src\optimizer_interface.jl:410 [inlined]
#   [9] holistic(y::Vector{Float64}, X::Matrix{Float64}, lambda::Int64, threshold::Float64, k::Int64)
#     @ Main .\In[55]:27
#  [10] top-level scope
#     @ In[62]:1

# %% [markdown]
# ## XGBoost

# %%
temp = IAI.XGBoostRegressor(random_seed = 1, max_categoric_levels_before_warning = 100)
grid_xgb = IAI.GridSearch(temp, num_estimators = 50, max_depth = 1:10, criterion = :mse)
IAI.fit!(grid_xgb, XtrainC, Array(ytrain), validation_criterion = :mse);

# %%
XGBmodel = IAI.get_learner(grid_xgb)
# Out:
# Fitted XGBoostRegressor

# %%
ypred = IAI.predict(XGBmodel, XtestC);

# %%
# Calculate metrics
mse = calculate_mse(ytest, ypred)
mae = calculate_mae(ytest, ypred)
osr2 = calculate_osr2(ytest, ypred)
# Print results
println("OSR2: ", osr2)
println("MAE: ", mae)
println("MSE: ", mse)
# Out:
# OSR2: -0.17827148348514732
# MAE: 0.12903501754075708
# MSE: 0.023793222901822994

# %% [markdown]
# ## Random Forest

# %%
temp = IAI.RandomForestRegressor(random_seed = 1, max_categoric_levels_before_warning = 100)
grid_rf = IAI.GridSearch(temp, num_trees = 100, minbucket = 1:10, criterion = :mse)
IAI.fit!(grid_rf, XtrainC, Array(ytrain), validation_criterion = :mse);
# Out:
# [ Warning: This copy of Interpretable AI software is for academic purposes only and not for commercial use.

# %%
RFmodel = IAI.get_learner(grid_rf)
# Out:
# Fitted RandomForestRegressor

# %%
ypred = IAI.predict(RFmodel, X_test);
# Out:
# UndefVarError: `X_test` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[42]:1

# %%
# Calculate metrics
mse = calculate_mse(ytest, ypred)
mae = calculate_mae(ytest, ypred)
osr2 = calculate_osr2(ytest, ypred)
# Print results
println("OSR2: ", osr2)
println("MAE: ", mae)
println("MSE: ", mse)
# Out:
# OSR2: -0.17827148348514732
# MAE: 0.12903501754075708
# MSE: 0.023793222901822994

# %% [markdown]
# ## Normalizing the Data

# %%
function detect_outliers_iqr(data)
    q1 = quantile(data, 0.25)
    q3 = quantile(data, 0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return findall((data .< lower_bound) .| (data .> upper_bound))
end

# Apply to a column
outliers_list = []
for i in 5:29
    outliers = detect_outliers_iqr(data[:, i])
    push!(outliers_list, outliers)
end
outliers_list

# %% [markdown]
# Let's normalize using Z-score since we have a fair amount of outliers.

# %%
function z_score_normalize(column)
    mean_val = mean(column)
    std_dev = std(column)
    return (column .- mean_val) ./ std_dev
end

# Normalize columns except the target
for col in 5:129
    data[:, col] = z_score_normalize(data[!, col])
end

# %%
data
# Out:
# 236×129 DataFrame
#  Row │ Tm       year   W      WIN.     avg_G_C     avg_GS_C    avg_MP_C    avg ⋯
#      │ String3  Int64  Int64  Float64  Float64     Float64     Float64     Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ MIL       2020     56    0.767   0.568752    0.233748    0.229019   -0. ⋯
#    2 │ TOR       2020     53    0.736  -1.73883    -0.651549   -0.0373343  -0.
#    3 │ LAL       2020     52    0.732   0.64441     0.19469    -0.310886   -0.
#    4 │ BOS       2020     48    0.667  -1.60264    -1.26605    -1.40365    -0.
#    5 │ DEN       2020     46    0.63    0.455265    0.311862    1.12526     1. ⋯
#    6 │ IND       2020     45    0.616   0.177851    0.832625    1.04248     0.
#    7 │ HOU       2020     44    0.611  -1.78927    -1.06816    -0.397271   -0.
#    8 │ OKC       2020     44    0.611  -1.00116    -1.01608    -0.839993   -0.
#    9 │ UTA       2020     44    0.611  -0.553514   -0.599473   -0.17411    -0. ⋯
#   10 │ MIA       2020     44    0.603   0.0769728  -0.117767   -0.0301355  -0.
#   11 │ POR       2020     35    0.473  -1.41098    -0.651549   -0.440463    0.
#   ⋮  │    ⋮       ⋮      ⋮       ⋮         ⋮           ⋮           ⋮           ⋱
#  227 │ PHI       2011     41    0.5    -0.358063   -0.664569   -1.51487    -1.
#  228 │ UTA       2011     39    0.476  -0.770401   -0.953592   -1.10131    -0. ⋯
#  229 │ IND       2011     37    0.451   0.430045   -0.104748   -0.0229368  -0.
#  230 │ MIL       2011     35    0.427  -0.414807   -0.64504    -0.769806   -0.
#  231 │ LAC       2011     32    0.39    0.228289    0.89772     1.39521     0.
#  232 │ DET       2011     30    0.366   1.06053     1.52264     1.27643    -0. ⋯
#  233 │ SAC       2011     24    0.293   0.0769728   0.546205   -0.260495   -0.
#  234 │ WAS       2011     23    0.28   -0.414807    0.663377   -0.656425   -0.
#  235 │ TOR       2011     22    0.268  -0.957025   -0.313054   -0.40447    -0.
#  236 │ CLE       2011     19    0.232   0.556142    0.676396    1.35922     0. ⋯
#                                                 122 columns and 215 rows omitted

# %%
train = data[sample,:];
test = data[Not(sample),:];
XtrainC = train[:,C_indices]
XtrainPG = train[:,PG_indices]
XtrainPF = train[:,PF_indices]
XtrainSF = train[:,SF_indices]
XtrainSG = train[:,SG_indices]
ytrain = train[:,4]
XtestC = test[:,C_indices]
XtestPG = test[:,PG_indices]
XtestPF = test[:,PF_indices]
XtestSF = test[:,SF_indices]
XtestSG = test[:,SG_indices]
ytest = test[:,4];
newXtrainC = newData(XtrainC)
newXtestC = newData(XtestC);
newXtrainPG = newData(XtrainPG)
newXtestPG = newData(XtestPG);
newXtrainPF = newData(XtrainPF)
newXtestPF = newData(XtestPF);
newXtrainSG = newData(XtrainSG)
newXtestSG = newData(XtestSG);
newXtrainSF = newData(XtrainSF)
newXtestSF = newData(XtestSF);

# %%
C_coeff = holistic(ytrain, newXtrainC, 1, .5, 50); # implement the function with lambda = 1, p = 0.5, and k = 8
pred= Matrix(newXtestC) * C_coeff
squared_error=(ytest .- pred).^2 
absolute_error=abs.(ytest .- pred)
MSE = mean(squared_error)
MAE = mean(absolute_error)
# Calculate the sum of squared residuals (SSR)
SSR = sum((ytest - pred).^2)
# Calculate the total sum of squares (TSS)
TSS = sum((ytest .- mean(ytest)).^2)
# Calculate OSR2
OSR2 = 1 - SSR/TSS
println("OSR2: ", OSR2)
println("MAE: ", MAE)
println("MSE: ", MSE)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-